# %%
from base_m_noise import *
import base_m_noise; importlib.reload(base_m_noise)

from fplanck import *
import fplanck; importlib.reload(fplanck)

from b_lam_dis import *
import b_lam_dis; importlib.reload(b_lam_dis)

from sympy import *

# %%
om, dt = 1, 0.000005
T = 300

Dm = list(range(1, 40, 5))
f, ax = num_an_burst(Dm, om, [0], f_, g, dt, T, leg='Dadd', an='simp')
f, ax = num_an_burst(Dm, om, [1], f_, g, dt, T, f=f, ax=ax, num=1, leg='Dadd', an='simp')
f, ax = num_an_burst(Dm, om, [2], f_, g, dt, T, f=f, ax=ax, num=2, leg='Dadd', an='simp')
f, ax = num_an_burst(Dm, om, [5], f_, g, dt, T, f=f, ax=ax, num=3, leg='Dadd', an='simp')
f, ax = num_an_burst(Dm, om, [10], f_, g, dt, T, f=f, ax=ax, num=4, leg='Dadd', an='simp')

# %%
m_ll_plot3(Da='0.0', dt='0.0005', iter='_par_thr5_meth2_', st=0)

# %%
st = "/Users/tphillips/multiplicative_noise/"
df=pd.read_csv(st+"c++/DATA/anal_FMPT_om1_Dm_Dadd.dat", sep=" ", header=None)
df=pd.read_csv(st+"mathematica/plots/fmpt_mon_n0_m_b1_Dm_Dadd.txt", sep='\t', header=None)
df = df.dropna(axis='columns', how='all')
df.columns=['x', 'D1', 'D2', 'm', 'Tn']

df

# Use mathematica Dadd = 0, n = 0, 0.2, 0.4, 0.6, Dm = 0.5, .., 10.5
# Out:
#       x     D1    D2     m        Tn
# 0     0    0.1   0.1   0.1  0.837632
# 1     0    0.1   0.1   0.2  0.861003
# 2     0    0.1   0.1   0.3  0.875182
# 3     0    0.1   0.1   0.4  0.883781
# 4     0    0.1   0.1   0.5  0.889106
# ...  ..    ...   ...   ...       ...
# 1795  0  100.0  10.0   9.6  0.047532
# 1796  0  100.0  10.0   9.7  0.047548
# 1797  0  100.0  10.0   9.8  0.047563
# 1798  0  100.0  10.0   9.9  0.047578
# 1799  0  100.0  10.0  10.0  0.047592
#
# [1800 rows x 5 columns]

# %%
## Create power law patterns 

om, dt = 1, 0.0001
T = 1000

Dm = list(range(1, 40, 5))
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[1], init=0.1, b=4, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[1], init=0.1, b=4, f=f, ax=ax, num=1, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[1], init=0.1, b=4, f=f, ax=ax, num=2, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[1], init=0.1, b=4, f=f, ax=ax, num=3, leg='n', an='simp')

# %%
om, dt, m = 1, 0.0001, 1.4
T = 1000

Dm = list(range(1, 40, 5))
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[m], init=0.1, b=4, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[m], init=0.1, b=4, f=f, ax=ax, num=1, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[m], init=0.1, b=4, f=f, ax=ax, num=2, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[m], init=0.1, b=4, f=f, ax=ax, num=3, leg='n', an='simp')

# %%
om, dt = 1, 0.0001
T = 2000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, init=0.1, b=4, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, init=0.1, b=4, f=f, ax=ax, num=1, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, init=0.1, b=4, f=f, ax=ax, num=2, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, init=0.1, b=4, f=f, ax=ax, num=3, leg='n', an='simp')

# %%
om, dt = 1, 0.0001
T = 2000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, init=0.1, b=4, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, init=0.1, b=4, f=f, ax=ax, num=1, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, init=0.1, b=4, f=f, ax=ax, num=2, leg='n', an='simp')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, init=0.1, b=4, f=f, ax=ax, num=3, leg='n', an='simp')

f2, ax2 = an_burst(f, ax, save='an_and_num_T')

# %%
from base_m_noise import *
import base_m_noise; importlib.reload(base_m_noise)

from fplanck import *
import fplanck; importlib.reload(fplanck)

from b_lam_dis import *
import b_lam_dis; importlib.reload(b_lam_dis)
# Out:
# <module 'b_lam_dis' from '/Users/tphillips/multiplicative_noise/python/b_lam_dis.py'>

# %%
om, dt, T = 1, 0.001, 30000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[1], init=0.1, a=0, b=30, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[1], init=0.1, a=0, b=30, f=f, ax=ax, num=1, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[1], init=0.1, a=0, b=30, f=f, ax=ax, num=2, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[1], init=0.1, a=0, b=30, f=f, ax=ax, num=3, leg='n', act='ref')

f2, ax2 = an_burst(f, ax, save='an_and_num_T_m1_b30', i=5)

# %%
om, dt, T = 1, 0.001, 5000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[1], init=0.1, a=0, b=10, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[1], init=0.1, a=0, b=10, f=f, ax=ax, num=1, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[1], init=0.1, a=0, b=10, f=f, ax=ax, num=2, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[1], init=0.1, a=0, b=10, f=f, ax=ax, num=3, leg='n', act='ref')

f2, ax2 = an_burst(f, ax, save='an_and_num_T_m1_b10', i=4)

# %%
om, dt = 1, 0.001
T = 5000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, init=0.1, a=0, b=4, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, init=0.1, a=0, b=4, f=f, ax=ax, num=1, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, init=0.1, a=0, b=4, f=f, ax=ax, num=2, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, init=0.1, a=0, b=4, f=f, ax=ax, num=3, leg='n', act='ref')

f2, ax2 = an_burst(f, ax, save='an_and_num_T')

# %%
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[0.8], init=0.1, a=0, b=4, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[0.8], init=0.1, a=0, b=4, f=f, ax=ax, num=1, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[0.8], init=0.1, a=0, b=4, f=f, ax=ax, num=2, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[0.8], init=0.1, a=0, b=4, f=f, ax=ax, num=3, leg='n', act='ref')

f2, ax2 = an_burst(f, ax, save='an_and_num_T_m0.8', i=3)

# %%
# Dadd
  
Dadd = [0, 1, 2, 5, 10] 
Dm = list(range(1, 40, 5)) 
 
om, dt, T = 1, 0.000005, 1000 
 
#bur_l = [] 
Dadd_l, Dm_l, b_dm = [], [], [] 

for j in Dadd: 
    for i in Dm:   
        tl, X, b_ = burst_counter(om, i, j, T, f_, g, dt, n_=0, m_=1, 
                                    X0=0, a=0, b=np.pi/2, act='ref') 
        b_dm.append(b_[0]/T)
        Dadd_l.append(j)
        Dm_l.append(i)

    #bur_l.append(b_dm)

data = pd.DataFrame({'D1': Dm_l, 'D2': Dadd_l, 'x': b_dm})

s = '/Users/tphillips/multiplicative_noise/sims/'
data.to_csv(s+'num_burst_om1_T1000_dtp000005.csv', sep='\t') 
#data

s = '/Users/tphillips/multiplicative_noise/sims/'
df=pd.read_csv(s+'num_burst_om1_T1000_dtp000005.csv', sep='\t') 
print(df.head())

df2 = df[df['D2']==0]
np.array(df2['x'])

# %%
# n

# run again just for 10, 30
  
#xcl = [np.pi/2, 4, 30]
#xcl = [np.pi/2, 4, 10, 30]
xcl = [4, 30]
ml = [1.0, 1.5]
nl = [0.0, 0.2, 0.4, 0.6] # , 0.8 
Dm = np.arange(0.5,11,0.5) # list(range(1, 40, 5)) 
 
#om, dt, T = 1, 0.000005, 1000 
#om, dt, T = 1, 0.0002, 100000 # dt = 0.0002
om, dt, T = 1, 0.000002, 10000
 
#bur_l = [] 
xc_l, n_l, m_l, Dm_l, b_dm = [], [], [], [], []
 
for xc in xcl:
    for m in ml: 
        for i in Dm:   
            for n in nl:
                tl, X, b_ = burst_counter(om, i, 0, T, f_mon, g_mon, dt, n_=n, m_=m, 
                                        X0=0.1, a=0, b=xc, act='ref') 
            
                #b_dm.append(b_[0]/T); Dm_l.append(i)
                b_dm.append(b_[0]/T); Dm_l.append(i)
                n_l.append(n); m_l.append(m)
                xc_l.append(xc)

                clear_output(wait=True)
                print("xc: ", xc, "D: ", i, "n: ", n, "m: ", m)

    #bur_l.append(b_dm)

data = pd.DataFrame({'xc': xc_l, 'D1': Dm_l, 'n': n_l, 'm': m_l, 'x': b_dm})

s = '/Users/tphillips/multiplicative_noise/sims/'
data.to_csv(s+'num_burst_om1_m1_T100000_dtp0002_xinit0p1.csv', sep='\t') 

#s = '/Users/tphillips/multiplicative_noise/sims/'
#df=pd.read_csv(s+'num_burst_om1_T1000_dtp000005.csv', sep='\t') 
#print(df.head())

#df2 = df[df['D2']==0]
#np.array(df2['x'])

# %%
# Trial 

print("simulation started")
  
xcl = [4] 
ml = [1.0] 
nl = [0.0, 0.2, 0.4, 0.6] 
Dm = np.arange(0.5,11,0.5)  
 
#om, dt, T = 1, 0.00005, 10000 #10000
om, dt, T = 1, 0.000002, 5000
#om, dt, T = 1,0.000005, 1000
  
Dm_l, b_trial_m1_x4 = [], []
 
for xc in xcl: 
    for m in ml: 
        for i in Dm:   
            for n in nl: 
                tl, X, b_ = burst_counter(om, i, 0, T, f_mon, g_mon, dt, n_=n, m_=m, 
                                        X0=0.1, a=0, b=xc, act='ref') 
            
                b_trial_m1_x4.append(b_[0]/T); Dm_l.append(i)

                clear_output(wait=True)
                print("xc: ", xc, "D: ", i, "n: ", n, "m: ", m)
# Out:
# xc:  4 D:  10.5 n:  0.6 m:  1.0

# %%
xcl = [4] 
ml = [1.5] 
nl = [0.0, 0.2, 0.4, 0.6] 
#Dm = np.arange(0.5,11,1)  
#om, dt, T = 1, 0.00005, 10000 #10000
#om, dt, T = 1, 0.000001, 10000

# best stats
Dm = np.arange(0.5,11,1)  
om, dt, T = 1, 0.000002, 20000
                  
Dm_l, b_trial_m15_x4 = [], []
 
for xc in xcl: 
    for m in ml: 
        for i in Dm:   
            for n in nl: 
                tl, X, b_ = burst_counter(om, i, 0, T, f_mon, g_mon, dt, n_=n, m_=m, 
                                        X0=0.1, a=0, b=xc, act='ref') 
            
                b_trial_m15_x4.append(b_[0]/T); Dm_l.append(i)

                clear_output(wait=True)
                print("xc: ", xc, "D: ", i, "n: ", n, "m: ", m)
# Out:
# xc:  4 D:  3.5 n:  0.4 m:  1.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/numba/core/serialize.py:29, in _numba_unpickle(address, bytedata, hashed)
#      26 _unpickled_memo = {}
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#      31
#      32     Parameters
#    (...)
#      41         unpickled object
#      42     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Input In [3], in <cell line: 14>()
#      16 for i in Dm:
#      17     for n in nl:
# ---> 18         tl, X, b_ = burst_counter(om, i, 0, T, f_mon, g_mon, dt, n_=n, m_=m,
#      19                                 X0=0.1, a=0, b=xc, act='ref')
# ...

# %%
data = pd.DataFrame({'x': b_trial_m1_x4})
s = '/Users/tphillips/multiplicative_noise/sims/'
data.to_csv(s+'b_trial_m1_x4.csv', sep='\t') 
print("cell has been run")

# %%
xcl = [30] 
ml = [1.0] 
nl = [0.0, 0.2, 0.4, 0.6] 
Dm = np.arange(0.5,11,0.5)  
 
#om, dt, T = 1, 0.00005, 10000 #10000
#om, dt, T = 1, 0.000001, 10000
  
Dm_l, b_trial_m1_x30 = [], []
 
for xc in xcl: 
    for m in ml: 
        for i in Dm:   
            for n in nl: 
                tl, X, b_ = burst_counter(om, i, 0, T, f_mon, g_mon, dt, n_=n, m_=m, 
                                        X0=0.1, a=0, b=xc, act='ref') 
            
                b_trial_m1_x30.append(b_[0]/T); Dm_l.append(i)

                clear_output(wait=True)
                print("xc: ", xc, "D: ", i, "n: ", n, "m: ", m)

# %%
from base_m_noise import *
import base_m_noise; importlib.reload(base_m_noise)

from b_lam_dis import *
import b_lam_dis; importlib.reload(b_lam_dis)
# Out:
# <module 'b_lam_dis' from '/Users/tphillips/multiplicative_noise/python/b_lam_dis.py'>

# %%
s = 14
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = plt.subplots(2, 2, figsize=(11, 7.3), sharex=True)

f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
#ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4)
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[0,0].set_ylabel(r'$T^{-1}$')
#

n_ = [0.0, 0.2, 0.4, 0.6]
ol = ['bo', 'g>', 'cs', 'm8', 'rd']
for j in range(len(n_)):
    ax[0,0].loglog(Dm_l[::2], b_trial_m1_x4[j::4*2], ol[j], markersize=8, mec = 'k', label=r'$n =$ {}'.format(n_[j])) 
#

f, ax[0,1] = an_burst(f, ax[0,1], i=5)
#ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30)
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=14)

f, ax[1,0] = an_burst(f, ax[1,0], i=2)
#ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4)
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=14)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')
#
#n_ = [0.0, 0.2, 0.4, 0.6]
#ol = ['bo', 'g>', 'cs', 'm8', 'rd']
#for j in range(len(n_)):
#    ax[1,0].loglog(Dm_l[j::4], b_trial[j::4], ol[j], markersize=8, mec = 'k', label=r'$n =$ {}'.format(n_[j])) 
#

ax[1,0].legend()

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
#ol = ['bo', 'go', 'co', 'mo', 'ro'] #['bo', 'g>', 'cs', 'm8', 'rd']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']
 
for i in range(len(nl)):
    #s = '/Users/tphillips/mpipks/multiplicative_noise/results/'
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)
    #print(df.head())

    #x, y = df['D'][1:], df['lam'][1:]
    x, y = df['D'], df['lam']
    #popt, _ = scipy.optimize.curve_fit(pow_fit, x, y)
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    ax[1,1].loglog(x, y, ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=11)
    
f.tight_layout()
#f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T100000_dt.png', bbox_inches='tight', format='png', dpi=120)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
s = 14
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = plt.subplots(2, 2, figsize=(10, 7), sharex=True)

f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4, sep=';')
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[0,0].set_ylabel(r'$T^{-1}$')

f, ax[0,1] = an_burst(f, ax[0,1], i=5)
ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30, sep=';')
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=14)

f, ax[1,0] = an_burst(f, ax[1,0], i=2)
ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4, sep=';')
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=14)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')

ax[1,0].legend()

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
#ol = ['bo', 'go', 'co', 'mo', 'ro'] #['bo', 'g>', 'cs', 'm8', 'rd']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']
 
for i in range(len(nl)):
    #s = '/Users/tphillips/mpipks/multiplicative_noise/results/'
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)
    #print(df.head())

    #x, y = df['D'][1:], df['lam'][1:]
    x, y = df['D'], df['lam']
    #popt, _ = scipy.optimize.curve_fit(pow_fit, x, y)
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    ax[1,1].loglog(x[::2], y[::2], ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=11)
    
f.tight_layout()
f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T10000_dtp000002_xinit0p1_2.png', bbox_inches='tight', format='png', dpi=120)

# %%
s = 14
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = np.arange(0.5,11,1).tolist()
f, ax = plt.subplots(2, 2, figsize=(10, 7), sharex=True)

# sep_num_burst_m1.0_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4, file='sep_num_burst_m1.0_om1_xc4.0_T20000_dtp000002_xinit0p1')
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[0,0].set_ylabel(r'$T^{-1}$')

# sep_num_burst_m1.0_om1_xc30.0_T20000_dtp000002_xinit0p1
f, ax[0,1] = an_burst(f, ax[0,1], i=5)
ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30, file='sep_num_burst_m1.0_om1_xc30.0_T20000_dtp000002_xinit0p1')
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=14)

# sep_num_burst_m1.5_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[1,0] = an_burst(f, ax[1,0], i=2)
ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4, file='sep_num_burst_m1.5_om1_xc4.0_T20000_dtp000002_xinit0p1')
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=14)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')

ax[1,0].legend()

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
#ol = ['bo', 'go', 'co', 'mo', 'ro'] #['bo', 'g>', 'cs', 'm8', 'rd']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']
 
for i in range(len(nl)):
    #s = '/Users/tphillips/mpipks/multiplicative_noise/results/'
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)
    #print(df.head())

    #x, y = df['D'][1:], df['lam'][1:]
    x, y = df['D'], df['lam']
    #popt, _ = scipy.optimize.curve_fit(pow_fit, x, y)
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    ax[1,1].loglog(x[::2], y[::2], ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=11)
    
f.tight_layout()
f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T10000_dtp000002_xinit0p1.png', bbox_inches='tight', format='png', dpi=120)

# %%
s = 14
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = [0.5, 1, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10]
#f, ax = plt.subplots(2, 2, figsize=(10, 7), sharex=True)
f, ax = plt.subplots(2, 2, figsize=(9.5, 6.7), sharex=True, sharey=True)

# sep_num_burst_m1.0_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4, file='best/sep_num_burst_m1.0_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[0,0].set_ylabel(r'$T^{-1}$')

# sep_num_burst_m1.0_om1_xc30.0_T20000_dtp000002_xinit0p1
f, ax[0,1] = an_burst(f, ax[0,1], i=5)
ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30, file='best/sep_num_burst_m1.0_om1_xc30.0_T40000_dtp000002_xinit0p1')
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=14)

# sep_num_burst_m1.5_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[1,0] = an_burst(f, ax[1,0], i=2)
ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4, file='best/sep_num_burst_m1.5_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=14)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')

ax[1,0].legend()

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
#ol = ['bo', 'go', 'co', 'mo', 'ro'] #['bo', 'g>', 'cs', 'm8', 'rd']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']
 
for i in range(len(nl)):
    #s = '/Users/tphillips/mpipks/multiplicative_noise/results/'
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)
    #print(df.head())

    #x, y = df['D'][1:], df['lam'][1:]
    x, y = df['D'], df['lam']
    #popt, _ = scipy.optimize.curve_fit(pow_fit, x, y)
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    ax[1,1].loglog(x[::2], y[::2], ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=11)
    
f.tight_layout()
f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T40000_dtp000002_xinit0p1_sharey.png', bbox_inches='tight', format='png', dpi=120)

# %%
# Run again !!! !!! !!! with ticks inside !!! !!! !!!

s = 17
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = [0.5, 1, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10]
#f, ax = plt.subplots(2, 2, figsize=(10, 7), sharex=True)
f, ax = plt.subplots(2, 2, figsize=(9.5, 6.7), sharex=True, sharey=True)

# sep_num_burst_m1.0_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4, file='best/sep_num_burst_m1.0_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=s)
ax[0,0].set_ylabel(r'$T^{-1}$')

# sep_num_burst_m1.0_om1_xc30.0_T20000_dtp000002_xinit0p1
f, ax[0,1] = an_burst(f, ax[0,1], i=5)
ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30, file='best/sep_num_burst_m1.0_om1_xc30.0_T40000_dtp000002_xinit0p1')
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=s)

# sep_num_burst_m1.5_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[1,0] = an_burst(f, ax[1,0], i=2)
ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4, file='best/sep_num_burst_m1.5_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=s)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')

ax[1,0].legend(ncol=2, fontsize=15)

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
#ol = ['bo', 'go', 'co', 'mo', 'ro'] #['bo', 'g>', 'cs', 'm8', 'rd']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']
 
for i in range(len(nl)):
    #s = '/Users/tphillips/mpipks/multiplicative_noise/results/'
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)
    #print(df.head())

    #x, y = df['D'][1:], df['lam'][1:]
    x, y = df['D'], df['lam']
    #popt, _ = scipy.optimize.curve_fit(pow_fit, x, y)
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    ax[1,1].loglog(x[::2], y[::2], ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    #ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    #ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

    ax[1,1].tick_params(bottom=True, left=True) 
    ax[1,1].tick_params(direction="in", length=4, width=1, grid_alpha=0.5) 

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=17)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=14)
    
f.tight_layout()
f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T40000_dtp000002_xinit0p1_sharey_2.png', bbox_inches='tight', format='png', dpi=120)

# %%
s = 14
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = [0.5, 1, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10]
#f, ax = plt.subplots(2, 2, figsize=(10, 7), sharex=True)
f, ax = plt.subplots(2, 2, figsize=(9.5, 6.7), sharex=True, sharey=True)

# sep_num_burst_m1.0_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4, file='best/sep_num_burst_m1.0_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[0,0].set_ylabel(r'$T^{-1}$')

# sep_num_burst_m1.0_om1_xc30.0_T20000_dtp000002_xinit0p1
f, ax[0,1] = an_burst(f, ax[0,1], i=5)
ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30, file='best/sep_num_burst_m1.0_om1_xc30.0_T40000_dtp000002_xinit0p1')
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=14)

# sep_num_burst_m1.5_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[1,0] = an_burst(f, ax[1,0], i=2)
ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4, file='best/sep_num_burst_m1.5_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=14)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')

ax[1,0].legend()

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']

f, ax[1,1] = an_burst(f, ax[1,1], i=6) 
f, ax[1,1] = an_burst(f, ax[1,1], i=0)
 
for i in range(len(nl)):
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)

    x, y = df['D'], df['lam']
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    ax[1,1].loglog(x[::2], y[::2], ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=11)
    
f.tight_layout()
#f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T40000_dtp000002_xinit0p1_sharey.png', bbox_inches='tight', format='png', dpi=120)

# %%
s = 14
params = {'xtick.labelsize': s, 'ytick.labelsize': s, 'legend.fontsize': s-1.5,
            'axes.labelsize': s, 'font.size': s, 'legend.handlelength': 2}
sns.set_theme(style="white", rc=params)

Dm = [0.5, 1, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10]
#f, ax = plt.subplots(2, 2, figsize=(10, 7), sharex=True)
f, ax = plt.subplots(2, 2, figsize=(9.5, 6.7), sharex=True, sharey=True)

# sep_num_burst_m1.0_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[0,0] = an_burst(f, ax[0,0], i=0) 
ax[0,0] = num_burst_(ax[0,0], Dm, m_=[1], b=4, file='best/sep_num_burst_m1.0_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[0,0].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[0,0].set_ylabel(r'$T^{-1}$')

# sep_num_burst_m1.0_om1_xc30.0_T20000_dtp000002_xinit0p1
f, ax[0,1] = an_burst(f, ax[0,1], i=5)
ax[0,1] = num_burst_(ax[0,1], Dm, m_=[1], b=30, file='best/sep_num_burst_m1.0_om1_xc30.0_T40000_dtp000002_xinit0p1')
ax[0,1].set_title(r"$m = 1$, $x_c = 30$", fontsize=14)

# sep_num_burst_m1.5_om1_xc4.0_T20000_dtp000002_xinit0p1
f, ax[1,0] = an_burst(f, ax[1,0], i=2)
ax[1,0] = num_burst_(ax[1,0], Dm, m_=[1.5], b=4, file='best/sep_num_burst_m1.5_om1_xc4.0_T40000_dtp000002_xinit0p1')
ax[1,0].set_title(r"$m = 1.5$, $x_c = 4$", fontsize=14)
ax[1,0].set_xlabel(r'$D$')
ax[1,0].set_ylabel(r'$T^{-1}$')

ax[1,0].legend()

nl = [0.0, 0.2, 0.4, 0.6]
sep = ['\t', '\t', '\t', ';']
ll = ['b-', 'g-', 'c-', 'm-', 'r-']
ol = ['wo', 'w>', 'ws', 'w8', 'wd']

#
x_,a_,D_,n_,m_ = symbols('x a D n m', positive=True) 
ps = (1/(2*D_*(x_**(2*m_))))*sp.exp((a_/D_)*(x_**(n_-2*m_+1))/(n_-2*m_+1))
expr = integrate(ps, (x_, 0, oo), conds='none')
#expr = integrate(ps, (x_, 0.1, oo), conds='none')

Dlist = np.arange(0.5,12,0.5)

def eta(a, xc, n, m, D, b=1):
    N = 1/expr.subs([(a_, a), (D_, D), (n_, n), (m_, m)]) 

    c = n - 2*m + 1
    frac = 1/(D*(xc**(2*m)))
    exp_ = (a/(D*b*b))*((xc**(c))/c)
    eta = frac*math.exp(exp_)
    #return(N*eta - N*frac*math.exp((a/(D*b*b))*((0.1**(c))/c)))
    return(N*eta)
    #return(2.5*N*eta*(D**0.72))

a, xc, m = 1, 4, 1
for n in nl:
    eta_l = [eta(a, xc, n, m, D) for D in Dlist] # works best
    ax[1,1].loglog(Dlist, eta_l, label='n={}'.format(n))
 #

for i in range(len(nl)):
    s = '/Users/tphillips/multiplicative_noise/results/'
    s2 = 'exp'+'_par_thr5_meth2_'+'Dm_Da'+'0.0'+'_m'+str(1.0)+'_n'+str(nl[i])+'_T500000_dt'+'0.0005'
    df = pd.read_csv(s+s2+'.csv', sep=sep[i], index_col=0)

    x, y = df['D'], df['lam']
    popt, _ = scipy.optimize.curve_fit(pow_fit, df['D'][1:], df['lam'][1:])
    ax[1,1].loglog(x, pow_fit(x, *popt), 'k--') # ll[i]
    print(popt[0], popt[1])
    ax[1,1].loglog(x[::2], y[::2], ol[i], markersize=8, mec = 'k', label=r'$n = $'+str(nl[i])) # ol[i]

    ax[1,1].grid(which='major', color='grey', linestyle='-', alpha=0.2)
    ax[1,1].grid(which='minor', color='grey', linestyle='--', alpha=0.15)

ax[1,1].set_title(r"$m = 1$, $x_c = 4$", fontsize=14)
ax[1,1].set_xlabel(r'$D$')
ax[1,1].set_ylabel(r'$\lambda$')
ax[1,1].legend(ncol=2, fontsize=11)
    
f.tight_layout()
#f.savefig('/Users/tphillips/multiplicative_noise/pics/4_mfpt_pow_plots_n_Da0_m_T40000_dtp000002_xinit0p1_sharey.png', bbox_inches='tight', format='png', dpi=120)
# Out:
# 0.2466605927771859 0.09719424805198303
# 0.2361147839336481 0.2864698144241589
# 0.219770110818413 0.5669989524471208
# 0.18586583573453494 1.0219806464868324

# %%
data = pd.DataFrame({'xc': xc_l, 'D1': Dm_l, 'n': n_l, 'm': m_l, 'x': b_dm})

s = '/Users/tphillips/multiplicative_noise/sims/'
data.to_csv(s+'num_burst_om1_m1_T100000_dtp0002_xinit0p1.csv', sep='\t')

# %%
data
# Out:
#             xc   D1    n    m        x
# 0     1.570796  0.5  0.0  1.0  0.67435
# 1     1.570796  0.5  0.2  1.0  0.58244
# 2     1.570796  0.5  0.4  1.0  0.49152
# 3     1.570796  0.5  0.6  1.0  0.39858
# 4     1.570796  0.5  0.8  1.0  0.29513
# ..         ...  ...  ...  ...      ...
# 437  10.000000  2.0  0.4  1.0  0.07374
# 438  10.000000  2.0  0.6  1.0  0.05213
# 439  10.000000  2.0  0.8  1.0  0.02313
# 440  10.000000  2.5  0.0  1.0  0.09928
# 441  10.000000  2.5  0.2  1.0  0.08422
#
# [442 rows x 5 columns]

# %%
from base_m_noise import *
import base_m_noise; importlib.reload(base_m_noise)

from fplanck import *
import fplanck; importlib.reload(fplanck)

from b_lam_dis import *
import b_lam_dis; importlib.reload(b_lam_dis)
# Out:
# <module 'b_lam_dis' from '/Users/tphillips/multiplicative_noise/python/b_lam_dis.py'>

# %%
#om, dt, T = 1, 0.001, 30000
om, dt, T = 1, 0.000005, 1000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[1], init=0.1, a=0, b=30, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[1], init=0.1, a=0, b=30, f=f, ax=ax, num=1, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[1], init=0.1, a=0, b=30, f=f, ax=ax, num=2, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[1], init=0.1, a=0, b=30, f=f, ax=ax, num=3, leg='n', act='ref')

f2, ax2 = an_burst(f, ax, i=5) # save='an_and_num_T_m1_b30'

# %%
om, dt, T = 1, 0.001, 10000

Dm = np.arange(0.5,11,0.5).tolist()
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.0, m_=[1], init=0.01, a=0, b=10, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.2, m_=[1], init=0.01, a=0, b=10, f=f, ax=ax, num=1, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.4, m_=[1], init=0.01, a=0, b=10, f=f, ax=ax, num=2, leg='n', act='ref')
f, ax = num_an_burst(Dm, om, [0], f_mon, g_mon, dt, T, n_=0.6, m_=[1], init=0.01, a=0, b=10, f=f, ax=ax, num=3, leg='n', act='ref')

f2, ax2 = an_burst(f, ax, save='an_and_num_T_m1_b10', i=4)

# %%
f, ax = plt.subplots(2, 2, figsize=(12, 8))

om, dt = 1, 0.000005
T = 300

# I should output file of numerics into data frame. 

Dm = list(range(1, 40, 5))
f, ax = num_an_burst(Dm, om, [0], f_, g, dt, T, leg='Dadd', an='simp', a=0)
f, ax = num_an_burst(Dm, om, [1], f_, g, dt, T, f=f, ax=ax, num=1, leg='Dadd', an='simp', a=0)
f, ax = num_an_burst(Dm, om, [2], f_, g, dt, T, f=f, ax=ax, num=2, leg='Dadd', an='simp', a=0)
f, ax = num_an_burst(Dm, om, [5], f_, g, dt, T, f=f, ax=ax, num=3, leg='Dadd', an='simp', a=0)
f, ax = num_an_burst(Dm, om, [10], f_, g, dt, T, f=f, ax=ax, num=4, leg='Dadd', an='simp', a=0)

# change size of circles
# and shapes
